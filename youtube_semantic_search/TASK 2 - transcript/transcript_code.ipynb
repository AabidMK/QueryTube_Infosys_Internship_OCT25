# %%
# !pip install google-api-python-client youtube-transcript-api pandas tqdm
# Out:
# Requirement already satisfied: google-api-python-client in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (2.160.0)
# Requirement already satisfied: youtube-transcript-api in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (1.2.3)
# Requirement already satisfied: pandas in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (2.2.0)
# Requirement already satisfied: tqdm in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (4.66.4)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client) (2.38.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client) (2.24.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from youtube-transcript-api) (0.7.1)
# Requirement already satisfied: requests in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from youtube-transcript-api) (2.32.5)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: colorama in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.66.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.26.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client) (3.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from requests->youtube-transcript-api) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from requests->youtube-transcript-api) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from requests->youtube-transcript-api) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from requests->youtube-transcript-api) (2025.10.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.6.1)
# [notice] A new release of pip is available: 25.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from youtube_transcript_api import YouTubeTranscriptApi
import pandas as pd
import time

def fetch_transcripts_simple(csv_file_path):
    """Simple version that saves only videoId and transcript columns"""
    # Read the original CSV
    df = pd.read_csv(csv_file_path)
    video_ids = df['videoId'].tolist()
   
    print(f"📁 Processing {len(video_ids)} videos from {csv_file_path}")
   
    transcripts = []
    available = []  # <-- Added for availability tracking

    for i, video_id in enumerate(video_ids, 1):
        print(f"🔄 Processing {i}/{len(video_ids)}: {video_id}")
       
        try:
            api = YouTubeTranscriptApi()
            result = api.fetch(video_id, languages=['en'])
            time.sleep(3) 
            text = ' '.join([snippet.text for snippet in result.snippets])
            text = ' '.join(text.split())  # Clean up
            transcripts.append(text)
            available.append(True)   # <-- Mark transcript available
            print("✅ Success")
        except Exception as e:
            print(f"❌ Failed: {e}")
            transcripts.append(None)
            available.append(False)  # <-- Mark transcript unavailable
       
        time.sleep(1)  # Be nice to YouTube
   
    # Create new DataFrame with only videoId and transcript
    result_df = pd.DataFrame({
        'videoId': video_ids,
        'transcript': transcripts
    })
   
    # Save only these two columns
    output_file = csv_file_path.replace('.csv', '_transcripts_only.csv')
    result_df.to_csv(output_file, index=False)
    print(f"💾 Saved to: {output_file}")
    print(f"📊 File contains: {len(result_df)} rows, 2 columns (videoId, transcript)")

    # ✅ Add transcript + availability columns to uploaded CSV
    df['transcript'] = transcripts
    df['is_transcript_available'] = available
    df.to_csv(csv_file_path, index=False)
    print(f"✅ Updated original CSV with new columns: transcript, is_transcript_available")
   
    return result_df

# Usage
csv_file_path = "ytdetails_transcript.csv"  # Your CSV file path
fetch_transcripts_simple(csv_file_path)
# Out:
# 📁 Processing 51 videos from ytdetails_transcript.csv
# 🔄 Processing 1/51: bshe96X5KkA
# ✅ Success
# 🔄 Processing 2/51: PtETUYa3i2Q
# ✅ Success
# 🔄 Processing 3/51: V7TMkZH1AkM
# ✅ Success
# 🔄 Processing 4/51: h4FRpDGuJyI
# ✅ Success
# 🔄 Processing 5/51: EWd3_I4X32g
# ✅ Success
# 🔄 Processing 6/51: M5B-xBmznok
# ✅ Success
# 🔄 Processing 7/51: Iqz7BWePOys
# ✅ Success
# 🔄 Processing 8/51: v73-ps01c5w
# ✅ Success
# 🔄 Processing 9/51: gJrjgg1KVL4
# ✅ Success
# 🔄 Processing 10/51: lvg8pBJ2kFg
# ✅ Success
# 🔄 Processing 11/51: K5KVEU3aaeQ
# ✅ Success
# 🔄 Processing 12/51: NClmyC6olC0
# ✅ Success
# 🔄 Processing 13/51: v7BNtpw53AA
# ✅ Success
# 🔄 Processing 14/51: gdiao7L9GjE
# ✅ Success
# 🔄 Processing 15/51: zVEH7Zt1j9A
# ✅ Success
# 🔄 Processing 16/51: fZmQ_aPXJAM
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=fZmQ_aPXJAM! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 17/51: AD43TVI2S0A
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=AD43TVI2S0A! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 18/51: AQdMaSaHWdM
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=AQdMaSaHWdM! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 19/51: YNtWJNPCPPs
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=YNtWJNPCPPs! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 20/51: BGZB9dn0GV4
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=BGZB9dn0GV4! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 21/51: yVl_G-F7m8c
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=yVl_G-F7m8c! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 22/51: c] code we have one more opportunity for improving this code look there are multiple places where we have defined our choices this is bad for two reasons one reason is that if we have a typo in our code our program is not going to work that's number one problem the second problem is that if tomorrow we decide to change our choices from R S and P to something else like 1 2 and three there are multiple places that we have to modify in programming we have this principle called dry which is short for don't repeat yourself so we don't want to have repetition or duplication in our code most of the time it's a bad practice practice so how can we solve this problem well we can generate this top hole based on this dictionary in this dictionary we have three key value pairs our keys are R S and P so let me show you how we can convert this dictionary to a tople with these values first I'm going to select this line and the rest of the code now we can convert all these lines to a comment by pressing command and slash on Mac or control and slash on Windows now all these lines are commented out so they're not going to get executed we only have the Declaration of our dictionary now let's print emojis dot look here we have a method called keys which Returns the keys of this dictionary using this structure dict keys let me show you so back to the terminal let's run our program all right here's what we get we get an object of type dict keys or dictionary keys and here we have R S and P but this is not exactly what we want what we want is a topple but this is very easy to fix we can pass the object that is returned from this method to the topple function and with this we get a top hole exactly like the top hole that we declared here so we can set choices to top hole of emojis do Keys okay with this technique we remov duplication in our code now let's bring back all the code here so one more time we press command and slash on Mac or control and slash on Windows okay now look there are other places where we have repeated our choices again if we have a typo our program is not going to work so realistically we need a single place for defining our choices to do that we can go to the top and declare a bunch of constants by convention we use uppercase letters to declare constants so we can declare a constant like rock and set it to R similarly scissors and paper this is a single place where we declare our choices now anywhere we have R S and P we replace them with our constants so I have selected R here now to select the next occurrence of R in this code we press command and D on Mac or control and D on Windows look this instance is also selected one more time we press command and D there you go now we have three cursors all of them selecting R so we can replace them all with rock in one go now to cancel multic cursor editing we press the escape button twice okay one more time we're going to select s we press command and D twice to select these two instances as well and replace this with scissors again we press the skape button twice done and the last one paper okay now we have a single place where we have defined our choices so no chance for typos and if we decide to change the choices from RS and P to something else in the future there is a single place we have to update we can change this to one two and three and everything will work okay but there is another benefit here look down here where we determine the winner our code is more descriptive so instead of comparing user choice and computer Choice with r and s we can clearly see that if the user has a rock and the computer has scissors the user is the winner hey there I hope you've been enjoying this video so far if you're finding this helpful and want to take your python skills even further I've got something really exciting for you this video is just a taste of what you will find in my full course python projects for beginners in the full course we dive deep into more projects ...
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=c] code we have one more opportunity for improving this code look there are multiple places where we have defined our choices this is bad for two reasons one reason is that if we have a typo in our code our program is not going to work that's number one problem the second problem is that if tomorrow we decide to change our choices from R S and P to something else like 1 2 and three there are multiple places that we have to modify in programming we have this principle called dry which is short for don't repeat yourself so we don't want to have repetition or duplication in our code most of the time it's a bad practice practice so how can we solve this problem well we can generate this top hole based on this dictionary in this dictionary we have three key value pairs our keys are R S and P so let me show you how we can convert this dictionary to a tople with these values first I'm going to select this line and the rest of the code now we can convert all these lines to a comment by pressing command and slash on Mac or control and slash on Windows now all these lines are commented out so they're not going to get executed we only have the Declaration of our dictionary now let's print emojis dot look here we have a method called keys which Returns the keys of this dictionary using this structure dict keys let me show you so back to the terminal let's run our program all right here's what we get we get an object of type dict keys or dictionary keys and here we have R S and P but this is not exactly what we want what we want is a topple but this is very easy to fix we can pass the object that is returned from this method to the topple function and with this we get a top hole exactly like the top hole that we declared here so we can set choices to top hole of emojis do Keys okay with this technique we remov duplication in our code now let's bring back all the code here so one more time we press command and slash on Mac or control and slash on Windows okay now look there are other places where we have repeated our choices again if we have a typo our program is not going to work so realistically we need a single place for defining our choices to do that we can go to the top and declare a bunch of constants by convention we use uppercase letters to declare constants so we can declare a constant like rock and set it to R similarly scissors and paper this is a single place where we declare our choices now anywhere we have R S and P we replace them with our constants so I have selected R here now to select the next occurrence of R in this code we press command and D on Mac or control and D on Windows look this instance is also selected one more time we press command and D there you go now we have three cursors all of them selecting R so we can replace them all with rock in one go now to cancel multic cursor editing we press the escape button twice okay one more time we're going to select s we press command and D twice to select these two instances as well and replace this with scissors again we press the skape button twice done and the last one paper okay now we have a single place where we have defined our choices so no chance for typos and if we decide to change the choices from RS and P to something else in the future there is a single place we have to update we can change this to one two and three and everything will work okay but there is another benefit here look down here where we determine the winner our code is more descriptive so instead of comparing user choice and computer Choice with r and s we can clearly see that if the user has a rock and the computer has scissors the user is the winner hey there I hope you've been enjoying this video so far if you're finding this helpful and want to take your python skills even further I've got something really exciting for you this video is just a taste of what you will find in my full course python projects for be ...
#
# The video is no longer available
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 23/51: 6GQRb4fGvtk
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=6GQRb4fGvtk! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 24/51: YRJbhFLLPyE
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=YRJbhFLLPyE! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 25/51: 9R3X0JoCLyU
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=9R3X0JoCLyU! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 26/51: GxmfcnU3feo
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=GxmfcnU3feo! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 27/51: 7IgVGSaQPaw
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=7IgVGSaQPaw! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 28/51: 3ZEMvvDFEdA
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=3ZEMvvDFEdA! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 29/51: yye7rSsiV6k
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=yye7rSsiV6k! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 30/51: IQDA39A44AA
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=IQDA39A44AA! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 31/51: CxLdTIIMXuM
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=CxLdTIIMXuM! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 32/51: OeEHJgzqS1k
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=OeEHJgzqS1k! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 33/51: Tef1e9FiSR0
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Tef1e9FiSR0! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 34/51: J-graiyPhpw
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=J-graiyPhpw! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 35/51: 3WphgC4wq0I
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=3WphgC4wq0I! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 36/51: 7IoNR3q2Jcc
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=7IoNR3q2Jcc! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 37/51: tdFsel6-bgo
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=tdFsel6-bgo! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 38/51: 8jP78iP6zVM
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=8jP78iP6zVM! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 39/51: Zl1hnNOAbFQ
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Zl1hnNOAbFQ! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 40/51: cVMh0SIjp9k
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=cVMh0SIjp9k! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 41/51: iw0znRuaYL8
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=iw0znRuaYL8! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 42/51: KkmSR7c9qLc
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=KkmSR7c9qLc! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 43/51: 4gX44uyGSHo
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=4gX44uyGSHo! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 44/51: FW49JfEXI3E
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=FW49JfEXI3E! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 45/51: Vrtx9G9lEuM
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Vrtx9G9lEuM! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 46/51: vE7Cy5csYbQ
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=vE7Cy5csYbQ! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 47/51: nzzPMc1X_gM
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=nzzPMc1X_gM! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 48/51: 27YP6n6pDh0
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=27YP6n6pDh0! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 49/51: kJOqIaGwQ7Y
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=kJOqIaGwQ7Y! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 50/51: E9BXvDElDlw
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=E9BXvDElDlw! This is most likely caused by:
#
# YouTube is blocking requests from your IP. This usually is due to one of the following reasons:
# - You have done too many requests and your IP has been blocked by YouTube
# - You are doing requests from an IP belonging to a cloud provider (like AWS, Google Cloud Platform, Azure, etc.). Unfortunately, most IPs from cloud providers are blocked by YouTube.
#
# Ways to work around this are explained in the "Working around IP bans" section of the README (https://github.com/jdepoix/youtube-transcript-api?tab=readme-ov-file#working-around-ip-bans-requestblocked-or-ipblocked-exception).
#
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 🔄 Processing 51/51: #NAME?
# ❌ Failed:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=#NAME?! This is most likely caused by:
#
# The video is no longer available
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# 💾 Saved to: ytdetails_transcript_transcripts_only.csv
# 📊 File contains: 51 rows, 2 columns (videoId, transcript)
# ✅ Updated original CSV with new columns: transcript, is_transcript_available
#                                               videoId  \
# 0                                         bshe96X5KkA
# 1                                         PtETUYa3i2Q
# 2                                         V7TMkZH1AkM
# 3                                         h4FRpDGuJyI
# 4                                         EWd3_I4X32g
# 5                                         M5B-xBmznok
# 6                                         Iqz7BWePOys
# 7                                         v73-ps01c5w
# 8                                         gJrjgg1KVL4
# 9                                         lvg8pBJ2kFg
# 10                                        K5KVEU3aaeQ
# 11                                        NClmyC6olC0
# 12                                        v7BNtpw53AA
# 13                                        gdiao7L9GjE
# 14                                        zVEH7Zt1j9A
# 15                                        fZmQ_aPXJAM
# 16                                        AD43TVI2S0A
# 17                                        AQdMaSaHWdM
# 18                                        YNtWJNPCPPs
# 19                                        BGZB9dn0GV4
# 20                                        yVl_G-F7m8c
# 21  c] code we have one more opportunity for impro...
# 22                                        6GQRb4fGvtk
# 23                                        YRJbhFLLPyE
# 24                                        9R3X0JoCLyU
# 25                                        GxmfcnU3feo
# 26                                        7IgVGSaQPaw
# 27                                        3ZEMvvDFEdA
# 28                                        yye7rSsiV6k
# 29                                        IQDA39A44AA
# 30                                        CxLdTIIMXuM
# 31                                        OeEHJgzqS1k
# 32                                        Tef1e9FiSR0
# 33                                        J-graiyPhpw
# 34                                        3WphgC4wq0I
# 35                                        7IoNR3q2Jcc
# 36                                        tdFsel6-bgo
# 37                                        8jP78iP6zVM
# 38                                        Zl1hnNOAbFQ
# 39                                        cVMh0SIjp9k
# 40                                        iw0znRuaYL8
# 41                                        KkmSR7c9qLc
# 42                                        4gX44uyGSHo
# 43                                        FW49JfEXI3E
# 44                                        Vrtx9G9lEuM
# 45                                        vE7Cy5csYbQ
# 46                                        nzzPMc1X_gM
# 47                                        27YP6n6pDh0
# 48                                        kJOqIaGwQ7Y
# 49                                        E9BXvDElDlw
# 50                                             #NAME?
#
#                                            transcript
# 0   [Music] AI is everywhere, but have you actuall...
# 1   [Music] AI is everywhere, but have you actuall...
# 2   [Music] Hey friends, I've got something exciti...
# 3   Microsoft just laid off 6,000 employees and th...
# 4   [Music] Welcome to part two of the ultimate Sp...
# 5   Hey guys, many of you have been waiting for pa...
# 6   hey everyone msh here a few days ago I publish...
# 7   hey everyone msh here a few days ago I publish...
# 8   [Music] welcome to the ultimate spring boot co...
# 9   hi guys many of you have been asking me for a ...
# 10  [Music] welcome to the complete python Mastery...
# 11  in this video we're diving into the top progra...
# 12  let's talk about the essential skills you need...
# 13  if you want to become a blockchain developer y...
# 14  2025 is just around the corner and if you're w...
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
# 50                                               None
